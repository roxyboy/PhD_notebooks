# %%
import pandas as pd
import xarray as xr
import os.path as op
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ddir = '/swot/SUM01/takaya/ftle/runs/'

# %%
ds = xr.open_dataset(op.join(ddir,'002/float_trajectories_netcdf/float_trajectories.0000000240.nc'))
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1, x0: 9995, y0: 9995)
# Coordinates:
#   * y0       (y0) float32 600.0 800.0 1000.0 ... 1999000.0 1999200.0 1999400.0
#   * x0       (x0) float32 600.0 800.0 1000.0 ... 1999000.0 1999200.0 1999400.0
#   * time     (time) int32 432000
# Data variables:
#     x        (time, y0, x0) float32 ...
#     y        (time, y0, x0) float32 ...
#     z        (time, y0, x0) float32 ...
#     u        (time, y0, x0) float32 ...
#     v        (time, y0, x0) float32 ...
#     vort     (time, y0, x0) float32 ...
#     lavd     (time, y0, x0) float32 ...

# %%
ds.x[0].plot(figsize=(12,10), cmap='cividis')

# %%
df = pd.read_csv(op.join(ddir,'float_trajectories.0000000000.001.001.csv'))
df
# Out:
#              npart  time         x         y    z         u         v  vort  \
# 0                1   0.0     562.5     562.5 -0.5  0.961637 -0.000975   0.0
# 1                2   0.0     687.5     562.5 -0.5  0.958507  0.001390   0.0
# 2                3   0.0     812.5     562.5 -0.5  0.955377  0.003754   0.0
# 3                4   0.0     937.5     562.5 -0.5  0.952247  0.006119   0.0
# 4                5   0.0    1062.5     562.5 -0.5  0.948416  0.008483   0.0
# 5                6   0.0    1187.5     562.5 -0.5  0.943886  0.010848   0.0
# 6                7   0.0    1312.5     562.5 -0.5  0.939355  0.013212   0.0
# 7                8   0.0    1437.5     562.5 -0.5  0.934824  0.015577   0.0
# 8                9   0.0    1562.5     562.5 -0.5  0.930293  0.017897   0.0
# 9               10   0.0    1687.5     562.5 -0.5  0.925763  0.020173   0.0
# 10              11   0.0    1812.5     562.5 -0.5  0.921232  0.022449   0.0
# ...

# %%
df = pd.read_csv(op.join(ddir,'float_trajectories.0000000004.001.001.csv'))
df
# Out:
#              npart    time              x           y    z         u  \
# 0                1  3600.0    4014.932398  663.480215 -0.5  0.930171
# 1                2  3600.0    4119.317789  670.901383 -0.5  0.926705
# 2                3  3600.0    4223.934211  678.223530 -0.5  0.923224
# 3                4  3600.0    4329.293204  685.380308 -0.5  0.919706
# 4                5  3600.0    4434.676869  692.661279 -0.5  0.916188
# 5                6  3600.0    4539.747843  700.009167 -0.5  0.912680
# 6                7  3600.0    4644.852778  706.992099 -0.5  0.909153
# 7                8  3600.0    4750.873180  713.946401 -0.5  0.905588
# 8                9  3600.0    4857.034274  721.340190 -0.5  0.902032
# 9               10  3600.0    4963.745524  728.826264 -0.5  0.898456
# 10              11  3600.0    5071.949038  736.326604 -0.5  0.896320
# 11              12  3600.0    5182.025644  744.083645 -0.5  0.894887
# 12              13  3600.0    5292.944386  752.042858 -0.5  0.893408
# ...

# %%
df = pd.read_csv(op.join(ddir,'float_trajectories.0000000008.001.001.csv'))
df
# Out:
#              npart    time              x            y    z         u  \
# 0                1  7200.0    7316.401367   973.753158 -0.5  0.902151
# 1                2  7200.0    7406.982900   986.521074 -0.5  0.900371
# 2                3  7200.0    7498.545476   999.502984 -0.5  0.898544
# 3                4  7200.0    7590.779979  1011.966104 -0.5  0.896657
# 4                5  7200.0    7683.571461  1024.318344 -0.5  0.894725
# 5                6  7200.0    7776.305487  1036.583105 -0.5  0.892763
# 6                7  7200.0    7869.814896  1048.473173 -0.5  0.890745
# 7                8  7200.0    7964.606872  1060.774389 -0.5  0.888677
# 8                9  7200.0    8061.314911  1073.767129 -0.5  0.887353
# 9               10  7200.0    8159.362157  1086.838824 -0.5  0.886430
# 10              11  7200.0    8259.529999  1099.953956 -0.5  0.885428
# 11              12  7200.0    8361.842464  1113.192844 -0.5  0.884347
# ...
